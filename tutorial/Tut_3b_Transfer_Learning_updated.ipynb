# %% [markdown]
# ## Tutorial 3b - Transfer Learning

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# Typically we do not train an entire Convolutional Neural Networks from scratch. One reason is that it is rare to have access to enough data to train the networks sufficiently. The other reason, as we have seen in labs 2 and 3, training neural networks can take a long time even on small 32 x 32 pixel images. Extending this to larger images such as the 3 x 224 x 224 that are commonly found in the ImageNet dataset could take weeks on a single GPUs.
#
# Instead, we can use pretrained networks such as the AlexNet, or VGG as feature extractors and train a smaller fully connected ANN to do our final classifications.

# %% [markdown]
# ## AlexNet in PyTorch
#
# Convolutional networks are very commonly used, meaning that there are often alternatives to
# training convolutional networks from scratch. In particular, researchers often release both
# the architecture and **the weights** of the networks they train.
#
# As an example, let's look at the AlexNet model, whose trained weights are included in `torchvision`.
# AlexNet was trained to classify images into one of many categories.
# The AlexNet can be imported and used as shown below.

# %%
# alexnet
import torchvision.models

alexNet = torchvision.models.alexnet(pretrained=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 155MB/s]

# %%
alexNet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Notice that the AlexNet model is split into two parts. There is a component that computes
# "features" using convolutions.

# %%
alexNet.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(inplace=True)
#   (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace=True)
#   (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# There is also a component that classifies the image based on the computed features.

# %%
alexNet.classifier
# Out:
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %% [markdown]
# ### AlexNet Features
#
# The first network can be used independently of the second. Specifically, it can be used
# to compute a set of **features** that can be used later on. This idea of using neural
# network activation *features* to represent images is an extremely important one, so it
# is important to understand the idea now.
#
# To see how we can do this, let's first load an image.

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import urllib

#load colour image
url ="https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews"
img = np.array(PIL.Image.open(urllib.request.urlopen(url)))

img = img[:,:,:3]
plt.imshow(img)

# %% [markdown]
# To use this image we need to convert it into a PyTorch tensor of the appropriate shape.

# %%
import torch

#convert to tensor
x = torch.from_numpy(img) # turn img into a PyTorch tensor
print(x.shape)

x = x.permute(2,0,1)      # move the channel dimension to the beginning
print(x.shape)
# Out:
# torch.Size([350, 210, 3])
# torch.Size([3, 350, 210])

# %% [markdown]
# Next, we feed the image x as an input to our alexNet feature network.

# %%
import torch

features = alexNet.features(x)
features.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-397538f828d9> in <cell line: 0>()
#       1 import torch
#       2
# ----> 3 features = alexNet.features(x)
#       4 features.shape
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# RuntimeError: Input type (unsigned char) and bias type (float) should be the same

# %% [markdown]
# **This results in an error!** Even when our batch size is 1, we still need the batch size dimension to be set to 1, so that the input
# follows the "NCHW" format (N = batch size, C = channels, H = height, W = width)

# %%
x = x.reshape([1, 3, 350, 210]) # add a dimension for batching
print(x.shape)
# Out:
# torch.Size([1, 3, 350, 210])

# %%
import torch
x = x.float()

features = alexNet.features(x)
features.shape # 9 by 5
# Out:
# torch.Size([1, 256, 9, 5])

# %% [markdown]
# The set of numbers in `features` is another way of representing our image `x`. Recall that
# our initial image `x` was also represented as a tensor, also a set of numbers representing
# pixel intensity. Geometrically speaking, we are using points in a high-dimensional space to
# represent the images. in our pixel representation, the axes in this high-dimensional space
# were different pixels. In our `features` representation, the axes are not as easily
# interpretable.
#
# But we will want to work with the `features` representation, because this representation
# makes classification easier. This representation organizes images in a more "useful" and
# "semantic" way than pixels.
#
# Let me be more specific:
# this set of `features` was trained on image classification. It turns out that
# **these features can be useful for performing other image-related tasks as well!**
# That is, if we want to perform an image classification task of our own (for example,
# classifying cancer biopsies, which is nothing like what AlexNet was trained to do),
# we might compute these AlexNet features, and then train a small model on top of those
# features. We replace the `classifier` portion of `AlexNet`, but keep its `features`
# portion intact.
#
# Somehow, through being trained on one type of image classification problem, AlexNet
# learned something general about representing images for the purposes of other
# classification tasks.
#
# ### AlexNet First Convolutions
#
# Here is the first convolution of AlexNet, applied to our image.

# %%
alexNetConv = alexNet.features[0]
y = alexNetConv(x)
y.shape
# Out:
# torch.Size([1, 64, 86, 51])

# %% [markdown]
# The output is a $1 \times 64 \times 86 \times 51$ tensor.

# %%
y = y.detach().numpy()
y = (y - y.min()) / (y.max() - y.min())
y.shape
# Out:
# (1, 64, 86, 51)

# %% [markdown]
# We can visualize each channel independently.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
for i in range(64):
    plt.subplot(8, 8, i+1)
    plt.imshow(y[0, i])

# %% [markdown]
# What happens to the output if we try to use other images? Specifically, what happens to the size of the feature tensor when you use a cat image vs. a dog image? What changes? What stays the same?

# %%
# features extracted would probably be the same. Color or shape...

# %% [markdown]
# ## Applying AlexNet on a Dataset
# In order to use transfer learning with AlexNet on a new dataset we will have to keep in mind how AlexNet was trained. AlexNet was trained on images of 3 x 224 x 224 images from the ImageNet dataset. These images are of higher resolution than what we have seen until now and are in colour. Hence, it would take significant effort to apply AlexNet to MNIST data, instead we will use another dataset.

# %% [markdown]
# ### Data Loading from a File
# To load our data we will use PyTorch's ImageFolder class which makes things a lot easier by allowing you to load data from a directory. For example, the training images are all stored in a directory path that looks like this:
#
# /datadir
#
#     /train
#         /class1
#         /class2
#         .
#         .
#     /val
#         /class1
#         /class2
#         .
#         .
#     /test
#         /class1
#         /class2
#         .
#         .
#
# You will need to mount your Google Drive to make this work with Colab.
#
# **It is important to copy the dataset in the host's local storage (e.g., unzip in `/root/datasets`)**

# %%
# mount our Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/Flower_Data_Large.zip' -d '/root/datasets'

# %% [markdown]
# If you have not uploaded the dataset to your google drive use this method.

# %%
! pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=ae46810ad445ee25be68798125b317cc025733e0e707f7101c433bc3a44d6e1f
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# !wget --no-check-certificate 'https://www.dropbox.com/scl/fi/8dniijwl4nskmfph91mc0/Flower_Data_Large.zip?rlkey=vrnplzh9yest31j775ch8h9ri&st=elbpuhll&dl=1' -O Flower_Data_Large.zip
# Out:
# --2025-02-27 17:26:55--  https://www.dropbox.com/scl/fi/8dniijwl4nskmfph91mc0/Flower_Data_Large.zip?rlkey=vrnplzh9yest31j775ch8h9ri&st=elbpuhll&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com/cd/0/inline/Ck7BrxS_mEogRA6yI_kA_SKGsvapNu5ViqquYn9Cc_51itwfD8A0nyv2im_IZeqSfRah6KOIMYAQqY3VhB4zW3FsIbfsWs4Fx5pB_3cDvRyjkF-vJe79RgHrup3HbAqVbEuPhTvmGcjyelbzL4SLfEdj/file?dl=1# [following]
# --2025-02-27 17:26:56--  https://ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com/cd/0/inline/Ck7BrxS_mEogRA6yI_kA_SKGsvapNu5ViqquYn9Cc_51itwfD8A0nyv2im_IZeqSfRah6KOIMYAQqY3VhB4zW3FsIbfsWs4Fx5pB_3cDvRyjkF-vJe79RgHrup3HbAqVbEuPhTvmGcjyelbzL4SLfEdj/file?dl=1
# Resolving ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com (ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com (ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Ck7KTgpiFVD4A8RzwvzymhX1Q-iJihcMyONJtX8TPM-_Hi29Nz4sQ769_HzDH_8L5_A9Hq_V1ewg5UGwxaLEKMRrOo9IZN-2Y1aKv7SGdMbJ-pl1cIqbylSjW9CBZa44Jx1Apmj1EZla5FK5QE8HYYnkTIKReU9h6RBDy2_pGc87PNBneWygIscdjIwy2gJvnm8AvV5BY5c59cSiY1Y8t3GvZ3yhQJkNq21xTUX0zPlUcNBCYPBTAJ6xTIILetyV709BqYfh7nfsZcM7ppD44UpqI-pD7jTMMPdRFxAEmpV2b08wVz6Rkav0Ef3mCimcZQqg281z3pVwX3YmKBVqFIiRp7gXg61yit7BGBOqrfDVygfZ1v2XUO_qFrmAgru76WI/file?dl=1 [following]
# --2025-02-27 17:26:56--  https://ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com/cd/0/inline2/Ck7KTgpiFVD4A8RzwvzymhX1Q-iJihcMyONJtX8TPM-_Hi29Nz4sQ769_HzDH_8L5_A9Hq_V1ewg5UGwxaLEKMRrOo9IZN-2Y1aKv7SGdMbJ-pl1cIqbylSjW9CBZa44Jx1Apmj1EZla5FK5QE8HYYnkTIKReU9h6RBDy2_pGc87PNBneWygIscdjIwy2gJvnm8AvV5BY5c59cSiY1Y8t3GvZ3yhQJkNq21xTUX0zPlUcNBCYPBTAJ6xTIILetyV709BqYfh7nfsZcM7ppD44UpqI-pD7jTMMPdRFxAEmpV2b08wVz6Rkav0Ef3mCimcZQqg281z3pVwX3YmKBVqFIiRp7gXg61yit7BGBOqrfDVygfZ1v2XUO_qFrmAgru76WI/file?dl=1
# Reusing existing connection to ucbe58063210f9bd9ac88553e950.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 223319407 (213M) [application/binary]
# Saving to: ‘Flower_Data_Large.zip’
#
# Flower_Data_Large.z 100%[===================>] 212.97M  94.0MB/s    in 2.3s
#
# 2025-02-27 17:26:59 (94.0 MB/s) - ‘Flower_Data_Large.zip’ saved [223319407/223319407]

# %%
# !unzip 'Flower_Data_Large.zip' -d '/root/datasets/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /root/datasets/train/daisy/5608389827_a42a46f760.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5608389827_a42a46f760.jpg
#   inflating: /root/datasets/train/daisy/8348621545_8f02b82662_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8348621545_8f02b82662_n.jpg
#   inflating: /root/datasets/train/daisy/13491959645_2cd9df44d6_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._13491959645_2cd9df44d6_n.jpg
#   inflating: /root/datasets/train/daisy/2621723097_736febb4a4_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2621723097_736febb4a4_n.jpg
#   inflating: /root/datasets/train/daisy/3450822975_7e77d67636_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3450822975_7e77d67636_n.jpg
#   inflating: /root/datasets/train/daisy/9489270024_1b05f08492_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9489270024_1b05f08492_m.jpg
#   inflating: /root/datasets/train/daisy/5087720485_c0914fb623.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5087720485_c0914fb623.jpg
#   inflating: /root/datasets/train/daisy/2481823240_eab0d86921.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2481823240_eab0d86921.jpg
#   inflating: /root/datasets/train/daisy/134409839_71069a95d1_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._134409839_71069a95d1_m.jpg
#   inflating: /root/datasets/train/daisy/2351206867_084e57bd97.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2351206867_084e57bd97.jpg
#   inflating: /root/datasets/train/daisy/174131220_c853df1287.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._174131220_c853df1287.jpg
#   inflating: /root/datasets/train/daisy/2520369272_1dcdb5a892_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2520369272_1dcdb5a892_m.jpg
#   inflating: /root/datasets/train/daisy/7416083788_fcb4c4f27e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7416083788_fcb4c4f27e_n.jpg
#   inflating: /root/datasets/train/daisy/5434913005_409c1e8b56_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5434913005_409c1e8b56_n.jpg
#   inflating: /root/datasets/train/daisy/7633425046_8293e3d0e9_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7633425046_8293e3d0e9_m.jpg
#   inflating: /root/datasets/train/daisy/7199968650_72afc16d31_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7199968650_72afc16d31_m.jpg
#   inflating: /root/datasets/train/daisy/8742143296_fed9fa007c.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8742143296_fed9fa007c.jpg
#   inflating: /root/datasets/train/daisy/1879567877_8ed2a5faa7_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1879567877_8ed2a5faa7_n.jpg
#   inflating: /root/datasets/train/daisy/4511693548_20f9bd2b9c_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4511693548_20f9bd2b9c_m.jpg
#   inflating: /root/datasets/train/daisy/4281102584_c548a69b81_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4281102584_c548a69b81_m.jpg
#   inflating: /root/datasets/train/daisy/1955336401_fbb206d6ef_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1955336401_fbb206d6ef_n.jpg
#   inflating: /root/datasets/train/daisy/4222584034_8964cbd3de.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4222584034_8964cbd3de.jpg
#   inflating: /root/datasets/train/daisy/9321854387_5f77c926cb_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9321854387_5f77c926cb_n.jpg
#   inflating: /root/datasets/train/daisy/4434592930_6610d51fca_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4434592930_6610d51fca_m.jpg
#   inflating: /root/datasets/train/daisy/8382667241_0f046cecdb_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8382667241_0f046cecdb_n.jpg
#   inflating: /root/datasets/train/daisy/7790614422_4557928ab9_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7790614422_4557928ab9_n.jpg
#   inflating: /root/datasets/train/daisy/1344985627_c3115e2d71_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1344985627_c3115e2d71_n.jpg
#   inflating: /root/datasets/train/daisy/3506866918_61dd5fc53b_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3506866918_61dd5fc53b_n.jpg
#   inflating: /root/datasets/train/daisy/4085794721_7cd88e0a6c_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4085794721_7cd88e0a6c_m.jpg
#   inflating: /root/datasets/train/daisy/3025866885_22fb0b61c6_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3025866885_22fb0b61c6_n.jpg
#   inflating: /root/datasets/train/daisy/3758221664_b19116d61f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3758221664_b19116d61f.jpg
#   inflating: /root/datasets/train/daisy/7358085448_b317d11cd5.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7358085448_b317d11cd5.jpg
#   inflating: /root/datasets/train/daisy/10391248763_1d16681106_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10391248763_1d16681106_n.jpg
#   inflating: /root/datasets/train/daisy/5665838969_fe217988b9_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5665838969_fe217988b9_m.jpg
#   inflating: /root/datasets/train/daisy/173350276_02817aa8d5.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._173350276_02817aa8d5.jpg
#   inflating: /root/datasets/train/daisy/5058708968_8bdcd29e63_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5058708968_8bdcd29e63_n.jpg
#   inflating: /root/datasets/train/daisy/7191221492_610035de7c_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7191221492_610035de7c_m.jpg
#   inflating: /root/datasets/train/daisy/14221836990_90374e6b34.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14221836990_90374e6b34.jpg
#   inflating: /root/datasets/train/daisy/4694730335_2553e77aa5_z.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4694730335_2553e77aa5_z.jpg
#   inflating: /root/datasets/train/daisy/4669117051_ce61e91b76.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4669117051_ce61e91b76.jpg
#   inflating: /root/datasets/train/daisy/2454280137_e1637536ae_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2454280137_e1637536ae_n.jpg
#   inflating: /root/datasets/train/daisy/3445110406_0c1616d2e3_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3445110406_0c1616d2e3_n.jpg
#   inflating: /root/datasets/train/daisy/10555826524_423eb8bf71_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10555826524_423eb8bf71_n.jpg
#   inflating: /root/datasets/train/daisy/4482623536_b9fb5ae41f_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4482623536_b9fb5ae41f_n.jpg
#   inflating: /root/datasets/train/daisy/2812442552_3eed5fb9f2_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2812442552_3eed5fb9f2_m.jpg
#   inflating: /root/datasets/train/daisy/9611923744_013b29e4da_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9611923744_013b29e4da_n.jpg
#   inflating: /root/datasets/train/daisy/4598422221_b37313a3e3_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4598422221_b37313a3e3_n.jpg
#   inflating: /root/datasets/train/daisy/5435513198_90ce39f1aa_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5435513198_90ce39f1aa_n.jpg
#   inflating: /root/datasets/train/daisy/267148092_4bb874af58.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._267148092_4bb874af58.jpg
#   inflating: /root/datasets/train/daisy/6480809573_76a0074b69_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6480809573_76a0074b69_n.jpg
#   inflating: /root/datasets/train/daisy/2556503265_63ae6b9e0e_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2556503265_63ae6b9e0e_m.jpg
#   inflating: /root/datasets/train/daisy/3939135368_0af5c4982a_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3939135368_0af5c4982a_n.jpg
#   inflating: /root/datasets/train/daisy/8120563761_ed5620664f_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8120563761_ed5620664f_m.jpg
#   inflating: /root/datasets/train/daisy/5809489674_5659b3ae5d_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5809489674_5659b3ae5d_n.jpg
#   inflating: /root/datasets/train/daisy/8709535323_a6bea3e43f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8709535323_a6bea3e43f.jpg
#   inflating: /root/datasets/train/daisy/433837534_1dbf798b73.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._433837534_1dbf798b73.jpg
#   inflating: /root/datasets/train/daisy/506018088_4f7a15a7c5_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._506018088_4f7a15a7c5_n.jpg
#   inflating: /root/datasets/train/daisy/3533954656_79156c8473.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3533954656_79156c8473.jpg
#   inflating: /root/datasets/train/daisy/2539552964_921cf645ba_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2539552964_921cf645ba_n.jpg
#   inflating: /root/datasets/train/daisy/14219214466_3ca6104eae_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14219214466_3ca6104eae_m.jpg
#   inflating: /root/datasets/train/daisy/2349640101_212c275aa7.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2349640101_212c275aa7.jpg
#   inflating: /root/datasets/train/daisy/5769217520_c90efc3c93_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5769217520_c90efc3c93_m.jpg
#   inflating: /root/datasets/train/daisy/8021540573_c56cf9070d_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8021540573_c56cf9070d_n.jpg
#   inflating: /root/datasets/train/daisy/4890424315_6a59696357_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4890424315_6a59696357_n.jpg
#   inflating: /root/datasets/train/daisy/5739768868_9f982684f9_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5739768868_9f982684f9_n.jpg
#   inflating: /root/datasets/train/daisy/3900172983_9312fdf39c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3900172983_9312fdf39c_n.jpg
#   inflating: /root/datasets/train/daisy/2641151167_3bf1349606_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2641151167_3bf1349606_m.jpg
#   inflating: /root/datasets/train/daisy/10555815624_dc211569b0.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10555815624_dc211569b0.jpg
#   inflating: /root/datasets/train/daisy/5435521200_92029bbe2b_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5435521200_92029bbe2b_n.jpg
#   inflating: /root/datasets/train/daisy/7377004908_5bc0cde347_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7377004908_5bc0cde347_n.jpg
#   inflating: /root/datasets/train/daisy/676120388_28f03069c3.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._676120388_28f03069c3.jpg
#   inflating: /root/datasets/train/daisy/3491933306_43cfe2cfbe.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3491933306_43cfe2cfbe.jpg
#   inflating: /root/datasets/train/daisy/8489463746_a9839bf7e4.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8489463746_a9839bf7e4.jpg
#   inflating: /root/datasets/train/daisy/799952628_bf836677fa_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._799952628_bf836677fa_n.jpg
#   inflating: /root/datasets/train/daisy/5794835_d15905c7c8_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5794835_d15905c7c8_n.jpg
#   inflating: /root/datasets/train/daisy/5110105726_53eb7a93be_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5110105726_53eb7a93be_m.jpg
#   inflating: /root/datasets/train/daisy/286875003_f7c0e1882d.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._286875003_f7c0e1882d.jpg
#   inflating: /root/datasets/train/daisy/11124324295_503f3a0804.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._11124324295_503f3a0804.jpg
#   inflating: /root/datasets/train/daisy/4117918318_3c8935289b_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4117918318_3c8935289b_m.jpg
#   inflating: /root/datasets/train/daisy/9346508462_f0af3163f4.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9346508462_f0af3163f4.jpg
#   inflating: /root/datasets/train/daisy/2476937534_21b285aa46_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2476937534_21b285aa46_n.jpg
#   inflating: /root/datasets/train/daisy/5796562389_ae43c83317_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5796562389_ae43c83317_m.jpg
#   inflating: /root/datasets/train/daisy/12348343085_d4c396e5b5_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._12348343085_d4c396e5b5_m.jpg
#   inflating: /root/datasets/train/daisy/2599662355_7782218c83.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2599662355_7782218c83.jpg
#   inflating: /root/datasets/train/daisy/5435522104_1d6a61b431_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5435522104_1d6a61b431_n.jpg
#   inflating: /root/datasets/train/daisy/2331133004_582772d58f_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2331133004_582772d58f_m.jpg
#   inflating: /root/datasets/train/daisy/9286947622_4822f4fc21.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9286947622_4822f4fc21.jpg
#   inflating: /root/datasets/train/daisy/5853276960_d08f90fff6.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5853276960_d08f90fff6.jpg
#   inflating: /root/datasets/train/daisy/3326037909_b5ae370722_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3326037909_b5ae370722_n.jpg
#   inflating: /root/datasets/train/daisy/3504430338_77d6a7fab4_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3504430338_77d6a7fab4_n.jpg
#   inflating: /root/datasets/train/daisy/4301689054_20519e5b68.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4301689054_20519e5b68.jpg
#   inflating: /root/datasets/train/daisy/14073784469_ffb12f3387_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14073784469_ffb12f3387_n.jpg
#   inflating: /root/datasets/train/daisy/3494265422_9dba8f2191_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3494265422_9dba8f2191_n.jpg
#   inflating: /root/datasets/train/daisy/175106495_53ebdef092_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._175106495_53ebdef092_n.jpg
#   inflating: /root/datasets/train/daisy/3275951182_d27921af97_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3275951182_d27921af97_n.jpg
#   inflating: /root/datasets/train/daisy/2561352120_7961d8263f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2561352120_7961d8263f.jpg
#   inflating: /root/datasets/train/daisy/1031799732_e7f4008c03.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1031799732_e7f4008c03.jpg
#   inflating: /root/datasets/train/daisy/3379332157_04724f6480.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3379332157_04724f6480.jpg
#   inflating: /root/datasets/train/daisy/10712722853_5632165b04.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10712722853_5632165b04.jpg
#   inflating: /root/datasets/train/daisy/7288989324_c25d9febbf.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7288989324_c25d9febbf.jpg
#   inflating: /root/datasets/train/daisy/4897587985_f9293ea1ed.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4897587985_f9293ea1ed.jpg
#   inflating: /root/datasets/train/daisy/3957488431_52a447c0e8_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3957488431_52a447c0e8_m.jpg
#   inflating: /root/datasets/train/daisy/2838487505_6c3b48efa5_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2838487505_6c3b48efa5_m.jpg
#   inflating: /root/datasets/train/daisy/3440366251_5b9bdf27c9_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3440366251_5b9bdf27c9_m.jpg
#   inflating: /root/datasets/train/daisy/10437929963_bc13eebe0c.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10437929963_bc13eebe0c.jpg
#   inflating: /root/datasets/train/daisy/9345273630_af3550031d.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9345273630_af3550031d.jpg
#   inflating: /root/datasets/train/daisy/6208851904_9d916ebb32_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6208851904_9d916ebb32_n.jpg
#   inflating: /root/datasets/train/daisy/4561871220_47f420ca59_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4561871220_47f420ca59_m.jpg
#   inflating: /root/datasets/train/daisy/5948835387_5a98d39eff_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5948835387_5a98d39eff_m.jpg
#   inflating: /root/datasets/train/daisy/105806915_a9c13e2106_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._105806915_a9c13e2106_n.jpg
#   inflating: /root/datasets/train/daisy/2551708158_1f10e81e11.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2551708158_1f10e81e11.jpg
#   inflating: /root/datasets/train/daisy/5765646947_82e95a9cc9_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5765646947_82e95a9cc9_n.jpg
#   inflating: /root/datasets/train/daisy/6776075110_1ea7a09dd4_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6776075110_1ea7a09dd4_n.jpg
#   inflating: /root/datasets/train/daisy/3337643329_accc9b5426.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3337643329_accc9b5426.jpg
#   inflating: /root/datasets/train/daisy/506348009_9ecff8b6ef.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._506348009_9ecff8b6ef.jpg
#   inflating: /root/datasets/train/daisy/14163875973_467224aaf5_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14163875973_467224aaf5_m.jpg
#   inflating: /root/datasets/train/daisy/12585131704_0f64b17059_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._12585131704_0f64b17059_m.jpg
#   inflating: /root/datasets/train/daisy/437859108_173fb33c98.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._437859108_173fb33c98.jpg
#   inflating: /root/datasets/train/daisy/8094774544_35465c1c64.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8094774544_35465c1c64.jpg
#   inflating: /root/datasets/train/daisy/10437770546_8bb6f7bdd3_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10437770546_8bb6f7bdd3_m.jpg
#   inflating: /root/datasets/train/daisy/4432271543_01c56ca3a9.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4432271543_01c56ca3a9.jpg
#   inflating: /root/datasets/train/daisy/813445367_187ecf080a_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._813445367_187ecf080a_n.jpg
#   inflating: /root/datasets/train/daisy/3764116502_f394428ee0_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3764116502_f394428ee0_n.jpg
#   inflating: /root/datasets/train/daisy/2479956481_8d1a9699be_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2479956481_8d1a9699be_n.jpg
#   inflating: /root/datasets/train/daisy/488202750_c420cbce61.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._488202750_c420cbce61.jpg
#   inflating: /root/datasets/train/daisy/12601254324_3cb62c254a_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._12601254324_3cb62c254a_m.jpg
#   inflating: /root/datasets/train/daisy/6210664514_f1d211217a.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6210664514_f1d211217a.jpg
#   inflating: /root/datasets/train/daisy/9515186037_3be48fe68f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9515186037_3be48fe68f.jpg
#   inflating: /root/datasets/train/daisy/2862944799_45bc8e7302.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2862944799_45bc8e7302.jpg
#   inflating: /root/datasets/train/daisy/8696022686_1f8d62c5cb_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8696022686_1f8d62c5cb_m.jpg
#   inflating: /root/datasets/train/daisy/4753134939_8e87649db6.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4753134939_8e87649db6.jpg
#   inflating: /root/datasets/train/daisy/2346726545_2ebce2b2a6.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2346726545_2ebce2b2a6.jpg
#   inflating: /root/datasets/train/daisy/1392131677_116ec04751.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1392131677_116ec04751.jpg
#   inflating: /root/datasets/train/daisy/1285423653_18926dc2c8_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1285423653_18926dc2c8_n.jpg
#   inflating: /root/datasets/train/daisy/302782756_d35cb3e468.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._302782756_d35cb3e468.jpg
#   inflating: /root/datasets/train/daisy/9244082319_b1f7e2d8b0_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9244082319_b1f7e2d8b0_n.jpg
#   inflating: /root/datasets/train/daisy/8759177308_951790e00d_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8759177308_951790e00d_m.jpg
#   inflating: /root/datasets/train/daisy/2713919471_301fcc941f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2713919471_301fcc941f.jpg
#   inflating: /root/datasets/train/daisy/4563059851_45a9d21a75.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4563059851_45a9d21a75.jpg
#   inflating: /root/datasets/train/daisy/5884807222_22f5326ba8_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5884807222_22f5326ba8_m.jpg
#   inflating: /root/datasets/train/daisy/5547758_eea9edfd54_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5547758_eea9edfd54_n.jpg
#   inflating: /root/datasets/train/daisy/9595857626_979c45e5bf_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9595857626_979c45e5bf_n.jpg
#   inflating: /root/datasets/train/daisy/144099102_bf63a41e4f_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._144099102_bf63a41e4f_n.jpg
#   inflating: /root/datasets/train/daisy/2619413565_61a6cd3ac9_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2619413565_61a6cd3ac9_m.jpg
#   inflating: /root/datasets/train/daisy/2590291468_2635d3e4e0_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2590291468_2635d3e4e0_n.jpg
#   inflating: /root/datasets/train/daisy/5722473541_ffac1ae67e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5722473541_ffac1ae67e_n.jpg
#   inflating: /root/datasets/train/daisy/4258408909_b7cc92741c_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4258408909_b7cc92741c_m.jpg
#   inflating: /root/datasets/train/daisy/2889325612_f2fc403ff0_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2889325612_f2fc403ff0_m.jpg
#   inflating: /root/datasets/train/daisy/4131565290_0585c4dd5a_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4131565290_0585c4dd5a_n.jpg
#   inflating: /root/datasets/train/daisy/4757448834_a29a9538c9_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4757448834_a29a9538c9_n.jpg
#   inflating: /root/datasets/train/daisy/3711892138_b8c953fdc1_z.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3711892138_b8c953fdc1_z.jpg
#   inflating: /root/datasets/train/daisy/134372449_0f7166d96c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._134372449_0f7166d96c_n.jpg
#   inflating: /root/datasets/train/daisy/2649404904_b7a91991bb_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2649404904_b7a91991bb_n.jpg
#   inflating: /root/datasets/train/daisy/5885826924_38fdc6bcaa_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5885826924_38fdc6bcaa_n.jpg
#   inflating: /root/datasets/train/daisy/3468498624_d082f99e98.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3468498624_d082f99e98.jpg
#   inflating: /root/datasets/train/daisy/3750771898_cfd50090ba_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3750771898_cfd50090ba_n.jpg
#   inflating: /root/datasets/train/daisy/1656856503_447e5b0f03.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1656856503_447e5b0f03.jpg
#   inflating: /root/datasets/train/daisy/8063844363_db3f4dea85.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8063844363_db3f4dea85.jpg
#   inflating: /root/datasets/train/daisy/1392946544_115acbb2d9.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1392946544_115acbb2d9.jpg
#   inflating: /root/datasets/train/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._15207766_fc2f1d692c_n.jpg
#   inflating: /root/datasets/train/daisy/515112668_a49c69455a.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._515112668_a49c69455a.jpg
#   inflating: /root/datasets/train/daisy/413815348_764ae83088.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._413815348_764ae83088.jpg
#   inflating: /root/datasets/train/daisy/483886997_27ee798327.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._483886997_27ee798327.jpg
#   inflating: /root/datasets/train/daisy/5714327423_50af0cffe9.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5714327423_50af0cffe9.jpg
#   inflating: /root/datasets/train/daisy/158869618_f1a6704236_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._158869618_f1a6704236_n.jpg
#   inflating: /root/datasets/train/daisy/12701063955_4840594ea6_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._12701063955_4840594ea6_n.jpg
#   inflating: /root/datasets/train/daisy/3336704121_cfeb67a7d7.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3336704121_cfeb67a7d7.jpg
#   inflating: /root/datasets/train/daisy/10993818044_4c19b86c82.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10993818044_4c19b86c82.jpg
#   inflating: /root/datasets/train/daisy/5459481183_18d2d49e44_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5459481183_18d2d49e44_m.jpg
#   inflating: /root/datasets/train/daisy/3456403987_5bd5fa6ece_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3456403987_5bd5fa6ece_n.jpg
#   inflating: /root/datasets/train/daisy/3356112863_75da8bca2c_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3356112863_75da8bca2c_m.jpg
#   inflating: /root/datasets/train/daisy/4141147800_813f660b47.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4141147800_813f660b47.jpg
#   inflating: /root/datasets/train/daisy/8681746439_d6beeefbf9.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8681746439_d6beeefbf9.jpg
#   inflating: /root/datasets/train/daisy/2019064575_7656b9340f_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2019064575_7656b9340f_m.jpg
#   inflating: /root/datasets/train/daisy/9299302012_958c70564c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9299302012_958c70564c_n.jpg
#   inflating: /root/datasets/train/daisy/6978826370_7b9aa7c7d5.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6978826370_7b9aa7c7d5.jpg
#   inflating: /root/datasets/train/daisy/2087343668_ef4fb95787_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2087343668_ef4fb95787_n.jpg
#   inflating: /root/datasets/train/daisy/4858518329_7563eb0baa_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4858518329_7563eb0baa_m.jpg
#   inflating: /root/datasets/train/daisy/102841525_bd6628ae3c.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._102841525_bd6628ae3c.jpg
#   inflating: /root/datasets/train/daisy/512477177_d9004cbcf1_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._512477177_d9004cbcf1_n.jpg
#   inflating: /root/datasets/train/daisy/2561371688_c80a4fe957_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2561371688_c80a4fe957_n.jpg
#   inflating: /root/datasets/train/daisy/9467543719_c4800becbb_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9467543719_c4800becbb_m.jpg
#   inflating: /root/datasets/train/daisy/11023277956_8980d53169_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._11023277956_8980d53169_m.jpg
#   inflating: /root/datasets/train/daisy/8694909523_3ca25d449d_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8694909523_3ca25d449d_n.jpg
#   inflating: /root/datasets/train/daisy/305160642_53cde0f44f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._305160642_53cde0f44f.jpg
#   inflating: /root/datasets/train/daisy/3337536080_1db19964fe.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3337536080_1db19964fe.jpg
#   inflating: /root/datasets/train/daisy/8708143485_38d084ac8c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8708143485_38d084ac8c_n.jpg
#   inflating: /root/datasets/train/daisy/4746633946_23933c0810.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4746633946_23933c0810.jpg
#   inflating: /root/datasets/train/daisy/2642408410_61545fdc83_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2642408410_61545fdc83_n.jpg
#   inflating: /root/datasets/train/daisy/163978992_8128b49d3e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._163978992_8128b49d3e_n.jpg
#   inflating: /root/datasets/train/daisy/6136947177_47ff445eb4_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6136947177_47ff445eb4_n.jpg
#   inflating: /root/datasets/train/daisy/5577555349_2e8490259b.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5577555349_2e8490259b.jpg
#   inflating: /root/datasets/train/daisy/144603918_b9de002f60_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._144603918_b9de002f60_m.jpg
#   inflating: /root/datasets/train/daisy/3717746329_53f515c6a6_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3717746329_53f515c6a6_m.jpg
#   inflating: /root/datasets/train/daisy/181007802_7cab5ee78e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._181007802_7cab5ee78e_n.jpg
#   inflating: /root/datasets/train/daisy/7702332000_3f21ef4571_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7702332000_3f21ef4571_n.jpg
#   inflating: /root/datasets/train/daisy/2045022175_ad087f5f60_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2045022175_ad087f5f60_n.jpg
#   inflating: /root/datasets/train/daisy/3639009391_0f910681b7.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3639009391_0f910681b7.jpg
#   inflating: /root/datasets/train/daisy/3285641623_da0e47f49a.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3285641623_da0e47f49a.jpg
#   inflating: /root/datasets/train/daisy/3627678863_557552c879_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3627678863_557552c879_m.jpg
#   inflating: /root/datasets/train/daisy/8127252886_96558c23d1.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8127252886_96558c23d1.jpg
#   inflating: /root/datasets/train/daisy/517054463_036db655a1_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._517054463_036db655a1_m.jpg
#   inflating: /root/datasets/train/daisy/14087947408_9779257411_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14087947408_9779257411_n.jpg
#   inflating: /root/datasets/train/daisy/43474673_7bb4465a86.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._43474673_7bb4465a86.jpg
#   inflating: /root/datasets/train/daisy/9496209717_25a6ebdab6_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9496209717_25a6ebdab6_m.jpg
#   inflating: /root/datasets/train/daisy/7630511450_02d3292e90.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7630511450_02d3292e90.jpg
#   inflating: /root/datasets/train/daisy/8983779970_9d3a6a3bf2_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8983779970_9d3a6a3bf2_n.jpg
#   inflating: /root/datasets/train/daisy/14114116486_0bb6649bc1_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14114116486_0bb6649bc1_m.jpg
#   inflating: /root/datasets/train/daisy/5973491805_556bba93cc.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5973491805_556bba93cc.jpg
#   inflating: /root/datasets/train/daisy/8645839873_0151fb92bf_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8645839873_0151fb92bf_n.jpg
#   inflating: /root/datasets/train/daisy/9120905231_329598304e.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9120905231_329598304e.jpg
#   inflating: /root/datasets/train/daisy/21652746_cc379e0eea_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._21652746_cc379e0eea_m.jpg
#   inflating: /root/datasets/train/daisy/4993492878_11fd4f5d12.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4993492878_11fd4f5d12.jpg
#   inflating: /root/datasets/train/daisy/2473825306_62fd5f8785_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2473825306_62fd5f8785_n.jpg
#   inflating: /root/datasets/train/daisy/4286053334_a75541f20b_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4286053334_a75541f20b_m.jpg
#   inflating: /root/datasets/train/daisy/6596277835_9f86da54bb.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6596277835_9f86da54bb.jpg
#   inflating: /root/datasets/train/daisy/3410906335_37e8a24b1c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3410906335_37e8a24b1c_n.jpg
#   inflating: /root/datasets/train/daisy/10140303196_b88d3d6cec.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10140303196_b88d3d6cec.jpg
#   inflating: /root/datasets/train/daisy/8964198962_6d8593b533.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8964198962_6d8593b533.jpg
#   inflating: /root/datasets/train/daisy/294451721_5106537b34.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._294451721_5106537b34.jpg
#   inflating: /root/datasets/train/daisy/10172379554_b296050f82_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10172379554_b296050f82_n.jpg
#   inflating: /root/datasets/train/daisy/8718637649_87a0d85190_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8718637649_87a0d85190_n.jpg
#   inflating: /root/datasets/train/daisy/3463313493_9497aa47e5_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3463313493_9497aa47e5_n.jpg
#   inflating: /root/datasets/train/daisy/4694734757_5c563d38dd_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4694734757_5c563d38dd_n.jpg
#   inflating: /root/datasets/train/daisy/10770585085_4742b9dac3_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10770585085_4742b9dac3_n.jpg
#   inflating: /root/datasets/train/daisy/5773652803_574b51414f_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5773652803_574b51414f_n.jpg
#   inflating: /root/datasets/train/daisy/4697206799_19dd2a3193_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4697206799_19dd2a3193_m.jpg
#   inflating: /root/datasets/train/daisy/450128527_fd35742d44.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._450128527_fd35742d44.jpg
#   inflating: /root/datasets/train/daisy/4654579740_6671a53627_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4654579740_6671a53627_m.jpg
#   inflating: /root/datasets/train/daisy/154332674_453cea64f4.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._154332674_453cea64f4.jpg
#   inflating: /root/datasets/train/daisy/9204730092_a7f2182347.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9204730092_a7f2182347.jpg
#   inflating: /root/datasets/train/daisy/4668543441_79040ca329_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4668543441_79040ca329_n.jpg
#   inflating: /root/datasets/train/daisy/11023272144_fce94401f2_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._11023272144_fce94401f2_m.jpg
#   inflating: /root/datasets/train/daisy/5874818796_3efbb8769d.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5874818796_3efbb8769d.jpg
#   inflating: /root/datasets/train/daisy/2635314490_e12d3b0f36_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2635314490_e12d3b0f36_m.jpg
#   inflating: /root/datasets/train/daisy/2001380507_19488ff96a_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2001380507_19488ff96a_n.jpg
#   inflating: /root/datasets/train/daisy/153210866_03cc9f2f36.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._153210866_03cc9f2f36.jpg
#   inflating: /root/datasets/train/daisy/835750256_3f91a147ef_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._835750256_3f91a147ef_n.jpg
#   inflating: /root/datasets/train/daisy/4540555191_3254dc4608_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4540555191_3254dc4608_n.jpg
#   inflating: /root/datasets/train/daisy/7410356270_9dff4d0e2e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7410356270_9dff4d0e2e_n.jpg
#   inflating: /root/datasets/train/daisy/367020749_3c9a652d75.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._367020749_3c9a652d75.jpg
#   inflating: /root/datasets/train/daisy/13977181862_f8237b6b52.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._13977181862_f8237b6b52.jpg
#   inflating: /root/datasets/train/daisy/2213954589_c7da4b1486.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2213954589_c7da4b1486.jpg
#   inflating: /root/datasets/train/daisy/5434901893_4550be3f84_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5434901893_4550be3f84_m.jpg
#   inflating: /root/datasets/train/daisy/10172567486_2748826a8b.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10172567486_2748826a8b.jpg
#   inflating: /root/datasets/train/daisy/8671824531_64b816949e_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8671824531_64b816949e_m.jpg
#   inflating: /root/datasets/train/daisy/391364010_4b0942d400_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._391364010_4b0942d400_m.jpg
#   inflating: /root/datasets/train/daisy/2480569557_f4e1f0dcb8_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2480569557_f4e1f0dcb8_n.jpg
#   inflating: /root/datasets/train/daisy/12193032636_b50ae7db35_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._12193032636_b50ae7db35_n.jpg
#   inflating: /root/datasets/train/daisy/422094774_28acc69a8b_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._422094774_28acc69a8b_n.jpg
#   inflating: /root/datasets/train/daisy/162362896_99c7d851c8_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._162362896_99c7d851c8_n.jpg
#   inflating: /root/datasets/train/daisy/9146733107_98b15d3892_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9146733107_98b15d3892_m.jpg
#   inflating: /root/datasets/train/daisy/4792826628_aa5e5a9804_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4792826628_aa5e5a9804_n.jpg
#   inflating: /root/datasets/train/daisy/1355787476_32e9f2a30b.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1355787476_32e9f2a30b.jpg
#   inflating: /root/datasets/train/daisy/2579018590_74359dcf1a_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2579018590_74359dcf1a_m.jpg
#   inflating: /root/datasets/train/daisy/3861452393_14d2f95157_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3861452393_14d2f95157_m.jpg
#   inflating: /root/datasets/train/daisy/10172636503_21bededa75_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10172636503_21bededa75_n.jpg
#   inflating: /root/datasets/train/daisy/14221848160_7f0a37c395.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14221848160_7f0a37c395.jpg
#   inflating: /root/datasets/train/daisy/5602738326_97121e007d_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5602738326_97121e007d_n.jpg
#   inflating: /root/datasets/train/daisy/4646886118_b5c5ceaf6d_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4646886118_b5c5ceaf6d_n.jpg
#   inflating: /root/datasets/train/daisy/525271784_013ddccd1b_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._525271784_013ddccd1b_m.jpg
#   inflating: /root/datasets/train/daisy/5665834973_76bd6c6523_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5665834973_76bd6c6523_m.jpg
#   inflating: /root/datasets/train/daisy/459931395_24bf6531fe_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._459931395_24bf6531fe_n.jpg
#   inflating: /root/datasets/train/daisy/8706810197_17b6c1f1e7.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8706810197_17b6c1f1e7.jpg
#   inflating: /root/datasets/train/daisy/495098110_3a4bb30042_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._495098110_3a4bb30042_n.jpg
#   inflating: /root/datasets/train/daisy/1374193928_a52320eafa.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1374193928_a52320eafa.jpg
#   inflating: /root/datasets/train/daisy/14307766919_fac3c37a6b_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14307766919_fac3c37a6b_m.jpg
#   inflating: /root/datasets/train/daisy/3975010332_3209f9f447_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3975010332_3209f9f447_m.jpg
#   inflating: /root/datasets/train/daisy/4544110929_a7de65d65f_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4544110929_a7de65d65f_n.jpg
#   inflating: /root/datasets/train/daisy/14021430525_e06baf93a9.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14021430525_e06baf93a9.jpg
#   inflating: /root/datasets/train/daisy/1396526833_fb867165be_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1396526833_fb867165be_n.jpg
#   inflating: /root/datasets/train/daisy/4861391074_c3e122dab0_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4861391074_c3e122dab0_m.jpg
#   inflating: /root/datasets/train/daisy/9158041313_7a6a102f7a_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9158041313_7a6a102f7a_n.jpg
#   inflating: /root/datasets/train/daisy/3750250718_eb61146c5f.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3750250718_eb61146c5f.jpg
#   inflating: /root/datasets/train/daisy/8932490012_cc08e690ba_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8932490012_cc08e690ba_n.jpg
#   inflating: /root/datasets/train/daisy/9094631844_1a6abca29e.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9094631844_1a6abca29e.jpg
#   inflating: /root/datasets/train/daisy/8709110478_60d12efcd4_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8709110478_60d12efcd4_n.jpg
#   inflating: /root/datasets/train/daisy/2578695910_5ab8ee17c1_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2578695910_5ab8ee17c1_n.jpg
#   inflating: /root/datasets/train/daisy/14264136211_9531fbc144.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14264136211_9531fbc144.jpg
#   inflating: /root/datasets/train/daisy/8383753520_8391dd80ee_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8383753520_8391dd80ee_m.jpg
#   inflating: /root/datasets/train/daisy/4333085242_bbeb3e2841_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4333085242_bbeb3e2841_m.jpg
#   inflating: /root/datasets/train/daisy/8085329197_41d53a21e2_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._8085329197_41d53a21e2_n.jpg
#   inflating: /root/datasets/train/daisy/4657354814_f368762c53_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4657354814_f368762c53_m.jpg
#   inflating: /root/datasets/train/daisy/11870378973_2ec1919f12.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._11870378973_2ec1919f12.jpg
#   inflating: /root/datasets/train/daisy/2901376034_cdb4bac26b_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2901376034_cdb4bac26b_m.jpg
#   inflating: /root/datasets/train/daisy/4923279674_e7f8e70794_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._4923279674_e7f8e70794_n.jpg
#   inflating: /root/datasets/train/daisy/3704306975_75b74497d8.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3704306975_75b74497d8.jpg
#   inflating: /root/datasets/train/daisy/3415180846_d7b5cced14_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3415180846_d7b5cced14_m.jpg
#   inflating: /root/datasets/train/daisy/909609509_a05ccb8127.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._909609509_a05ccb8127.jpg
#   inflating: /root/datasets/train/daisy/7669550908_bc5a11276f_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7669550908_bc5a11276f_n.jpg
#   inflating: /root/datasets/train/daisy/2536529152_33ef3ee078_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2536529152_33ef3ee078_n.jpg
#   inflating: /root/datasets/train/daisy/6095817094_3a5b1d793d.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6095817094_3a5b1d793d.jpg
#   inflating: /root/datasets/train/daisy/2488902131_3417698611_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2488902131_3417698611_n.jpg
#   inflating: /root/datasets/train/daisy/3080880039_4f1bd592e5_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3080880039_4f1bd592e5_n.jpg
#   inflating: /root/datasets/train/daisy/5981645737_29eceac291_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5981645737_29eceac291_m.jpg
#   inflating: /root/datasets/train/daisy/5794839_200acd910c_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5794839_200acd910c_n.jpg
#   inflating: /root/datasets/train/daisy/7335886184_d06a83f640.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7335886184_d06a83f640.jpg
#   inflating: /root/datasets/train/daisy/6054952060_c88612f3c5_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._6054952060_c88612f3c5_n.jpg
#   inflating: /root/datasets/train/daisy/3310644753_5607eb96a4_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3310644753_5607eb96a4_m.jpg
#   inflating: /root/datasets/train/daisy/14245834619_153624f836.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._14245834619_153624f836.jpg
#   inflating: /root/datasets/train/daisy/5110110938_9da91455c4_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5110110938_9da91455c4_m.jpg
#   inflating: /root/datasets/train/daisy/9529916092_de70623523_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9529916092_de70623523_n.jpg
#   inflating: /root/datasets/train/daisy/7538403124_f2fc48750a.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7538403124_f2fc48750a.jpg
#   inflating: /root/datasets/train/daisy/2908212142_5437fa67ff_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2908212142_5437fa67ff_n.jpg
#   inflating: /root/datasets/train/daisy/754248840_95092de274.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._754248840_95092de274.jpg
#   inflating: /root/datasets/train/daisy/9242705328_eee8402a8d.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9242705328_eee8402a8d.jpg
#   inflating: /root/datasets/train/daisy/1286274236_1d7ac84efb_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._1286274236_1d7ac84efb_n.jpg
#   inflating: /root/datasets/train/daisy/5883162120_dc7274af76_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5883162120_dc7274af76_n.jpg
#   inflating: /root/datasets/train/daisy/11642632_1e7627a2cc.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._11642632_1e7627a2cc.jpg
#   inflating: /root/datasets/train/daisy/538920244_59899a78f8_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._538920244_59899a78f8_n.jpg
#   inflating: /root/datasets/train/daisy/172882635_4cc7b86731_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._172882635_4cc7b86731_m.jpg
#   inflating: /root/datasets/train/daisy/2521408074_e6f86daf21_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._2521408074_e6f86daf21_n.jpg
#   inflating: /root/datasets/train/daisy/9593034725_0062f0d24e_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9593034725_0062f0d24e_n.jpg
#   inflating: /root/datasets/train/daisy/169371301_d9b91a2a42.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._169371301_d9b91a2a42.jpg
#   inflating: /root/datasets/train/daisy/7630520686_e3a61ac763.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._7630520686_e3a61ac763.jpg
#   inflating: /root/datasets/train/daisy/3713290261_8a66de23ab.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3713290261_8a66de23ab.jpg
#   inflating: /root/datasets/train/daisy/5014137563_d03eb0ed75_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._5014137563_d03eb0ed75_n.jpg
#   inflating: /root/datasets/train/daisy/10466290366_cc72e33532.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._10466290366_cc72e33532.jpg
#   inflating: /root/datasets/train/daisy/9175280426_40ecc395b8_m.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._9175280426_40ecc395b8_m.jpg
#   inflating: /root/datasets/train/daisy/3640845041_80a92c4205_n.jpg
#   inflating: /root/datasets/__MACOSX/train/daisy/._3640845041_80a92c4205_n.jpg
#   inflating: /root/datasets/train/daisy/3588872598_e0f9a1d2a1_m.jpg
# ...
#   inflating: /root/datasets/__MACOSX/val/tulips/._17199499591_67b64b21ed_m.jpg
#   inflating: /root/datasets/val/tulips/15275478257_fbd5850708_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15275478257_fbd5850708_n.jpg
#   inflating: /root/datasets/val/tulips/19425920580_cdc8f49aed_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._19425920580_cdc8f49aed_n.jpg
#   inflating: /root/datasets/val/tulips/14671196461_b725727229_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14671196461_b725727229_m.jpg
#   inflating: /root/datasets/val/tulips/16074109313_2cc14c7d16.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16074109313_2cc14c7d16.jpg
#   inflating: /root/datasets/val/tulips/16645809126_613b1e3ebe_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16645809126_613b1e3ebe_m.jpg
#   inflating: /root/datasets/val/tulips/17167151059_a53bfe0b02.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17167151059_a53bfe0b02.jpg
#   inflating: /root/datasets/val/tulips/15756524087_823cf86bd8_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15756524087_823cf86bd8_m.jpg
#   inflating: /root/datasets/val/tulips/17309951996_552d632cbb_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17309951996_552d632cbb_n.jpg
#   inflating: /root/datasets/val/tulips/17719248689_cfd5d2f228_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17719248689_cfd5d2f228_n.jpg
#   inflating: /root/datasets/val/tulips/15147464747_594599c855_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15147464747_594599c855_m.jpg
#   inflating: /root/datasets/val/tulips/15458787091_3edc6cd1eb.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15458787091_3edc6cd1eb.jpg
#   inflating: /root/datasets/val/tulips/14674388855_2da18e375a_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14674388855_2da18e375a_m.jpg
#   inflating: /root/datasets/val/tulips/16930121391_a4092ecf00_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16930121391_a4092ecf00_n.jpg
#   inflating: /root/datasets/val/tulips/14674071872_2df55466d5_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14674071872_2df55466d5_m.jpg
#   inflating: /root/datasets/val/tulips/16907559551_05ded87fb2_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16907559551_05ded87fb2_n.jpg
#   inflating: /root/datasets/val/tulips/16680930777_7e7f292fc5_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16680930777_7e7f292fc5_n.jpg
#   inflating: /root/datasets/val/tulips/16937554595_3e1de22f9c.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16937554595_3e1de22f9c.jpg
#   inflating: /root/datasets/val/tulips/17282288501_e8738c9cfb_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17282288501_e8738c9cfb_n.jpg
#   inflating: /root/datasets/val/tulips/16169741783_deeab1a679_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16169741783_deeab1a679_m.jpg
#   inflating: /root/datasets/val/tulips/17198868382_697b23c715_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17198868382_697b23c715_n.jpg
#   inflating: /root/datasets/val/tulips/17324469461_2b318aff8d_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17324469461_2b318aff8d_m.jpg
#   inflating: /root/datasets/val/tulips/16765283686_0315ae00a8.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16765283686_0315ae00a8.jpg
#   inflating: /root/datasets/val/tulips/16139439153_fbdee29a10_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16139439153_fbdee29a10_n.jpg
#   inflating: /root/datasets/val/tulips/15452909878_0c4941f729_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15452909878_0c4941f729_m.jpg
#   inflating: /root/datasets/val/tulips/17159816388_deafbebdb0.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17159816388_deafbebdb0.jpg
#   inflating: /root/datasets/val/tulips/16862349256_0a1f91ab53.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16862349256_0a1f91ab53.jpg
#   inflating: /root/datasets/val/tulips/14491997336_36ba524713.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14491997336_36ba524713.jpg
#   inflating: /root/datasets/val/tulips/17078576150_6f272ce73f_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17078576150_6f272ce73f_n.jpg
#   inflating: /root/datasets/val/tulips/17189456156_6fc1067831.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17189456156_6fc1067831.jpg
#   inflating: /root/datasets/val/tulips/16930105456_8b826dc4a8_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16930105456_8b826dc4a8_n.jpg
#   inflating: /root/datasets/val/tulips/17318339476_54479b6660_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17318339476_54479b6660_n.jpg
#   inflating: /root/datasets/val/tulips/17295127995_62eff434fe_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17295127995_62eff434fe_n.jpg
#   inflating: /root/datasets/val/tulips/15881325303_f00807a051_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15881325303_f00807a051_n.jpg
#   inflating: /root/datasets/val/tulips/16670377091_87987f50a4_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16670377091_87987f50a4_n.jpg
#   inflating: /root/datasets/val/tulips/16751015081_af2ef77c9a_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16751015081_af2ef77c9a_n.jpg
#   inflating: /root/datasets/val/tulips/14861513337_4ef0bfa40d.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14861513337_4ef0bfa40d.jpg
#   inflating: /root/datasets/val/tulips/15275199229_962387f24d.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15275199229_962387f24d.jpg
#   inflating: /root/datasets/val/tulips/19413898445_69344f9956_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._19413898445_69344f9956_n.jpg
#   inflating: /root/datasets/val/tulips/16677199221_eab3f22378_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16677199221_eab3f22378_n.jpg
#   inflating: /root/datasets/val/tulips/17994129033_bbd0acba62_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17994129033_bbd0acba62_n.jpg
#   inflating: /root/datasets/val/tulips/17146928665_600fa3a1f1_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17146928665_600fa3a1f1_n.jpg
#   inflating: /root/datasets/val/tulips/16711791713_e54bc9c1af_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16711791713_e54bc9c1af_n.jpg
#   inflating: /root/datasets/val/tulips/17862445825_f7031d6f26.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17862445825_f7031d6f26.jpg
#   inflating: /root/datasets/val/tulips/16717320956_d4b00807f2.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16717320956_d4b00807f2.jpg
#   inflating: /root/datasets/val/tulips/15082212714_ff87e8fcb1_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15082212714_ff87e8fcb1_m.jpg
#   inflating: /root/datasets/val/tulips/17224410762_402455ed8f.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17224410762_402455ed8f.jpg
#   inflating: /root/datasets/val/tulips/16700863150_ddaa4d89b4_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16700863150_ddaa4d89b4_n.jpg
#   inflating: /root/datasets/val/tulips/18406629611_4d1edcf23b_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._18406629611_4d1edcf23b_n.jpg
#   inflating: /root/datasets/val/tulips/16485607329_e66d5960bc_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16485607329_e66d5960bc_m.jpg
#   inflating: /root/datasets/val/tulips/15647243236_2778501cf5_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15647243236_2778501cf5_n.jpg
#   inflating: /root/datasets/val/tulips/16309287412_5cc4d58bd1_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16309287412_5cc4d58bd1_n.jpg
#   inflating: /root/datasets/val/tulips/15516715153_08abc9bb20_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15516715153_08abc9bb20_n.jpg
#   inflating: /root/datasets/val/tulips/16680998737_6f6225fe36.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16680998737_6f6225fe36.jpg
#   inflating: /root/datasets/val/tulips/16862351376_f0fcc6fc91_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16862351376_f0fcc6fc91_n.jpg
#   inflating: /root/datasets/val/tulips/17189526216_fa24dd541a_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17189526216_fa24dd541a_n.jpg
#   inflating: /root/datasets/val/tulips/17469578564_35a8360f58.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17469578564_35a8360f58.jpg
#   inflating: /root/datasets/val/tulips/14866400927_3a59899df3_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14866400927_3a59899df3_m.jpg
#   inflating: /root/datasets/val/tulips/15147473067_7c5498eb0e_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15147473067_7c5498eb0e_m.jpg
#   inflating: /root/datasets/val/tulips/15049902081_dd85361f8c_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15049902081_dd85361f8c_m.jpg
#   inflating: /root/datasets/val/tulips/17094167287_865840060d_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17094167287_865840060d_n.jpg
#   inflating: /root/datasets/val/tulips/15275144259_f9a18ec9cb.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15275144259_f9a18ec9cb.jpg
#   inflating: /root/datasets/val/tulips/16644790896_7b296ecd67_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16644790896_7b296ecd67_n.jpg
#   inflating: /root/datasets/val/tulips/14651383746_419dc73634_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14651383746_419dc73634_m.jpg
#   inflating: /root/datasets/val/tulips/16680927427_07ca6e4552_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16680927427_07ca6e4552_n.jpg
#   inflating: /root/datasets/val/tulips/15632065904_0d9caf174b.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15632065904_0d9caf174b.jpg
#   inflating: /root/datasets/val/tulips/15090146325_b7e1249e60.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15090146325_b7e1249e60.jpg
#   inflating: /root/datasets/val/tulips/15922772266_1167a06620.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15922772266_1167a06620.jpg
#   inflating: /root/datasets/val/tulips/17159349572_c0c51599f7_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17159349572_c0c51599f7_n.jpg
#   inflating: /root/datasets/val/tulips/14674067742_73c2602aa6_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14674067742_73c2602aa6_m.jpg
#   inflating: /root/datasets/val/tulips/15029962436_3e50c1f30f_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15029962436_3e50c1f30f_n.jpg
#   inflating: /root/datasets/val/tulips/17012955700_7141d29eee.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17012955700_7141d29eee.jpg
#   inflating: /root/datasets/val/tulips/17844723633_da85357fe3.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17844723633_da85357fe3.jpg
#   inflating: /root/datasets/val/tulips/16702117379_c25bff70e9.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16702117379_c25bff70e9.jpg
#   inflating: /root/datasets/val/tulips/15149373026_93aacc65c5.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15149373026_93aacc65c5.jpg
#   inflating: /root/datasets/val/tulips/18245124970_e68fd3f3c3.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._18245124970_e68fd3f3c3.jpg
#   inflating: /root/datasets/val/tulips/16471277547_a0a5509377_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16471277547_a0a5509377_n.jpg
#   inflating: /root/datasets/val/tulips/15275190769_0ed7bbf490.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15275190769_0ed7bbf490.jpg
#   inflating: /root/datasets/val/tulips/15516736553_b169b67195_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15516736553_b169b67195_n.jpg
#   inflating: /root/datasets/val/tulips/17066864992_1cbc4fc908.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17066864992_1cbc4fc908.jpg
#   inflating: /root/datasets/val/tulips/17408197905_829c4d7940_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17408197905_829c4d7940_m.jpg
#   inflating: /root/datasets/val/tulips/14746916178_40403cc57e.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14746916178_40403cc57e.jpg
#   inflating: /root/datasets/val/tulips/16677542612_a78a8ca8b3_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16677542612_a78a8ca8b3_m.jpg
#   inflating: /root/datasets/val/tulips/16702188449_3dacce90b2_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16702188449_3dacce90b2_m.jpg
#   inflating: /root/datasets/val/tulips/17720403638_94cfcd8d5c_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17720403638_94cfcd8d5c_n.jpg
#   inflating: /root/datasets/val/tulips/16986144192_55e0e6c152.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16986144192_55e0e6c152.jpg
#   inflating: /root/datasets/val/tulips/14487943607_651e8062a1_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14487943607_651e8062a1_m.jpg
#   inflating: /root/datasets/val/tulips/16938892686_3613ea68e8_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16938892686_3613ea68e8_n.jpg
#   inflating: /root/datasets/val/tulips/16265883604_92be82b973.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16265883604_92be82b973.jpg
#   inflating: /root/datasets/val/tulips/15052586652_56a82de133_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._15052586652_56a82de133_m.jpg
#   inflating: /root/datasets/val/tulips/16110795216_b3e44697b4_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16110795216_b3e44697b4_m.jpg
#   inflating: /root/datasets/val/tulips/16594995743_ce72c61201_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16594995743_ce72c61201_n.jpg
#   inflating: /root/datasets/val/tulips/16582481123_06e8e6b966_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16582481123_06e8e6b966_n.jpg
#   inflating: /root/datasets/val/tulips/17066862602_7530f21efe.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17066862602_7530f21efe.jpg
#   inflating: /root/datasets/val/tulips/16951623209_00fb7ec1b1_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16951623209_00fb7ec1b1_n.jpg
#   inflating: /root/datasets/val/tulips/17199496791_3caaf5e278_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17199496791_3caaf5e278_m.jpg
#   inflating: /root/datasets/val/tulips/17202535346_ab828e779b.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17202535346_ab828e779b.jpg
#   inflating: /root/datasets/val/tulips/17165583356_38cb1f231d_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17165583356_38cb1f231d_n.jpg
#   inflating: /root/datasets/val/tulips/18378581986_5cd1494d08_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._18378581986_5cd1494d08_n.jpg
#   inflating: /root/datasets/val/tulips/17907238905_1ae121f8d9_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._17907238905_1ae121f8d9_m.jpg
#   inflating: /root/datasets/val/tulips/16098264209_38fe491093.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16098264209_38fe491093.jpg
#   inflating: /root/datasets/val/tulips/14674389605_df3c0bcfa1_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._14674389605_df3c0bcfa1_m.jpg
#   inflating: /root/datasets/val/tulips/16732302779_8aa56f255d_n.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16732302779_8aa56f255d_n.jpg
#   inflating: /root/datasets/val/tulips/16062072523_1be3c0b61f.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16062072523_1be3c0b61f.jpg
#   inflating: /root/datasets/val/tulips/16055807744_000bc07afc_m.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16055807744_000bc07afc_m.jpg
#   inflating: /root/datasets/val/tulips/16862422576_5226e8d1d0.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16862422576_5226e8d1d0.jpg
#   inflating: /root/datasets/val/tulips/16265876844_0a149c4f76.jpg
#   inflating: /root/datasets/__MACOSX/val/tulips/._16265876844_0a149c4f76.jpg

# %%
import time
import os
import numpy as np
import torch

import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt

# %%
# define training and test data directories
data_dir = '/root/datasets/'
train_dir = os.path.join(data_dir, 'train/')
val_dir = os.path.join(data_dir, 'val/')

# classes are folders in each directory with these names
classes = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
# load and transform data using ImageFolder

# resize all images to 224 x 224
data_transform = transforms.Compose([transforms.RandomResizedCrop(224),
                                      transforms.ToTensor()])

train_data = datasets.ImageFolder(train_dir, transform=data_transform)
val_data = datasets.ImageFolder(val_dir, transform=data_transform)

# print out some data stats
print('Num training images: ', len(train_data))
print('Num validation images: ', len(val_data))
# Out:
# Num training images:  3039
# Num validation images:  540

# %%
# define dataloader parameters
batch_size  = 256
num_workers = 0

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers, shuffle=True) # num_workers is hardware
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size,
                                          num_workers=num_workers, shuffle=True)

# %%
# Visualize some sample data

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, int(20/2), idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### AlexNet Implementation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim #for gradient descent

# alexnet
import torchvision.models

torch.manual_seed(1) # set the random seed

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# confirm output from AlexNet feature extraction
alexNet = torchvision.models.alexnet(pretrained=True) # make sure pretrained = True
features = alexNet.features(images)
features.shape
# Out:
# torch.Size([256, 256, 6, 6])

# %%
# no reason for 256 and 256 be the same. 6 by 6 filter

# %%
#Artifical Neural Network Architecture
class ANNClassifier(nn.Module):
    def __init__(self):
        super(ANNClassifier, self).__init__()
        self.fc1 = nn.Linear(256 * 6 * 6, 10)
        self.fc2 = nn.Linear(10, 5) # 5 different class

    def forward(self, x):
        x = x.view(-1, 256 * 6 * 6) #flatten feature data
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def get_accuracy(model, train=False):
    if train:
        data_loader = train_loader
    else:
        data_loader = val_loader

    correct = 0
    total = 0
    for imgs, labels in data_loader:


        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          imgs = imgs.cuda()
          labels = labels.cuda()
        #############################################

        output = model(ALNC(imgs))

        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %%
def train(model, data, batch_size=20, num_epochs=1):
    #train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size)
    # train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           #num_workers=num_workers, shuffle=True)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    start_time=time.time()
    for epoch in range(num_epochs):
        mini_b=0
        mini_batch_correct = 0
        Mini_batch_total = 0
        for imgs, labels in iter(train_loader):


            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              imgs = imgs.cuda()
              labels = labels.cuda()
            #############################################

          #### ALNC is alexNet.features (AlexNet without classifier) ####

            out = model(ALNC(imgs))             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch



            ##### Mini_batch Accuracy ##### We don't compute accuracy on the whole training set in every iteration!
            pred = out.max(1, keepdim=True)[1]
            mini_batch_correct = pred.eq(labels.view_as(pred)).sum().item()
            Mini_batch_total = imgs.shape[0]
            train_acc.append((mini_batch_correct / Mini_batch_total))
           ###########################

          # save the current training information
            iters.append(n)
            losses.append(float(loss)/batch_size)             # compute *average* loss
            val_acc.append(get_accuracy(model, train=False))  # compute validation accuracy
            n += 1
            mini_b += 1
            print("Iteration: ",n,'Progress: % 6.2f ' % ((epoch * len(train_loader) + mini_b) / (num_epochs * len(train_loader))*100),'%', "Time Elapsed: % 6.2f s " % (time.time()-start_time))


        print ("Epoch %d Finished. " % epoch ,"Time per Epoch: % 6.2f s "% ((time.time()-start_time) / (epoch +1)))


    end_time= time.time()
    # plotting
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Training")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Validation Accuracy")
    plt.legend(loc='best')
    plt.show()

    train_acc.append(get_accuracy(model, train=True))
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))
    print ("Total time:  % 6.2f s  Time per Epoch: % 6.2f s " % ( (end_time-start_time), ((end_time-start_time) / num_epochs) ))

# %%
# !nvidia-smi
# Out:
# Thu Feb 27 17:37:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
use_cuda = True

model = ANNClassifier()
ALNC = alexNet.features

if use_cuda and torch.cuda.is_available():
  ALNC.cuda()
  model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

#proper model
train(model, [], batch_size=batch_size, num_epochs=1)
# Out:
# CUDA is available!  Training on GPU ...
# Iteration:  1 Progress:   8.33  % Time Elapsed:   4.54 s
# Iteration:  2 Progress:  16.67  % Time Elapsed:   8.04 s
# Iteration:  3 Progress:  25.00  % Time Elapsed:  12.32 s
# Iteration:  4 Progress:  33.33  % Time Elapsed:  15.64 s
# Iteration:  5 Progress:  41.67  % Time Elapsed:  18.89 s
# Iteration:  6 Progress:  50.00  % Time Elapsed:  22.55 s
# Iteration:  7 Progress:  58.33  % Time Elapsed:  26.62 s
# Iteration:  8 Progress:  66.67  % Time Elapsed:  29.89 s
# Iteration:  9 Progress:  75.00  % Time Elapsed:  33.15 s
# Iteration:  10 Progress:  83.33  % Time Elapsed:  37.11 s
# Iteration:  11 Progress:  91.67  % Time Elapsed:  40.96 s
# Iteration:  12 Progress:  100.00  % Time Elapsed:  44.08 s
# Epoch 0 Finished.  Time per Epoch:  44.08 s
# Final Training Accuracy: 0.6581112207963146
# Final Validation Accuracy: 0.6796296296296296
# Total time:   44.08 s  Time per Epoch:  44.08 s

# %% [markdown]
# The above example is only used to demonstrate the implementation of transfer learning. You are encouraged to explore different set of parameters and ways to improve the speed of the training. Note also that there is a larger dataset of flowers which you may want to try out as well to see if you can improve on the classification accuracy.

# %% [markdown]
# # Preventing Overfitting
#
# In the last few weeks we discussed the idea of **overfitting**,
# where a neural network model learns about the quirks of the training data,
# rather than information that is generalizable to the task
# at hand. We also briefly discussed idea of **underfitting**, but not in as much depth.
#
# The reason we did not discuss underfitting much is because nowadays,
# practitioners tend to avoid underfitting altogether by opting for more
# powerful models. Since computation is (relatively) cheap,
# and overfitting is much easier to detect, it is more straightforward
# to build a high-capacity model and use known techniques to prevent
# overfitting. So, always start with slightly more *capacity* than you need,
# then use some of the many strategies to prevent overfitting.
#
# We've actually already discussed several strategies for preventing overfitting:
#
# - Use a larger training set
# - Use a smaller network
# - Weight-sharing (as in convolutional neural networks)
# - Early stopping
# - Transfer Learning
#
# Some of these are more practical than others. For example, collecting a larger training
# set may be impractical or expensive in practice. Using a smaller network means that we need
# to restart training, rather than use what we already know about hyperparameters and appropriate
# weights.
#
# **Early stopping** was introduced in lab 2,
# where we did not use the trained weights from the last training iteration
# as our ``final'' model.
# Instead, we used a model (a set of weights) from a previous
# iteration of training. We chose the iteration/epoch to use based on
# the training curve.
#
# **Transfer learning** where we use pre-trained weights of a different model (e.g. AlexNet)
# as part of our neural network also helps prevent overfitting.
# The architectures and weights of AlexNet was trained using a larger
# dataset of over a million images, and was trained to solve a different image classification problem.
# Nevertheless, transfer learning allows us to leverage information
# from larger data sets with low computational cost. Effectively acting like a larger training set.
#
# These are only some of the techniques for preventing overfitting. We'll discuss more techniques today,
# including:
#
# - Data Normalization
# - Data Augmentation
# - Weight Decay
# - Model Averaging
# - Dropout
#
# We will use the MNIST digit recognition problem as a running example. Since we are studying overfitting,
# I will artificially reduce the number of training examples to 200.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# for reproducibility
torch.manual_seed(1)

mnist_data = datasets.MNIST('data', train=True, download=True, transform=transforms.ToTensor())
mnist_data = list(mnist_data)
mnist_train = mnist_data[:200]     #  200 train images
mnist_val   = mnist_data[300:2300] # 2000 validation images
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.5MB/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 476kB/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.43MB/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.25MB/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# We will also use the `MNISTClassifier` from the last few weeks as our base model:

# %%
class MNISTClassifier(nn.Module):
    def __init__(self):
        super(MNISTClassifier, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 50)
        self.layer2 = nn.Linear(50, 20)
        self.layer3 = nn.Linear(20, 10)
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = F.relu(self.layer1(flattened))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %% [markdown]
# And of course, our training code, with minor modifications that we will explain as we go along.

# %%
def train(model, train, valid, batch_size=20, num_iters=1, learn_rate=0.01, weight_decay=0):
    train_loader = torch.utils.data.DataLoader(train,
                                               batch_size=batch_size,
                                               shuffle=True) # shuffle after every epoch
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learn_rate, momentum=0.9, weight_decay=weight_decay)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    while True:
        if n >= num_iters:
            break
        for imgs, labels in iter(train_loader):
            model.train() #*****************************#
            out = model(imgs)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch

            # save the current training information
            if n % 10 == 9:
                iters.append(n)
                losses.append(float(loss)/batch_size)        # compute *average* loss
                train_acc.append(get_accuracy(model, train)) # compute training accuracy
                val_acc.append(get_accuracy(model, valid))   # compute validation accuracy
            n += 1

    # plotting
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")

    plt.subplot(1,2,2)
    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))


train_acc_loader = torch.utils.data.DataLoader(mnist_train, batch_size=100)
val_acc_loader = torch.utils.data.DataLoader(mnist_val, batch_size=1000)

def get_accuracy(model, data):
    correct = 0
    total = 0
    model.eval() #*********#
    for imgs, labels in torch.utils.data.DataLoader(data, batch_size=64):
        output = model(imgs)
        pred = output.max(1, keepdim=True)[1] # get the index of the max logit
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %% [markdown]
# Without any intervention, our model gets to about 52-53% accuracy on the validation set.

# %%
model = MNISTClassifier()
train(model, mnist_train, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.7475

# %% [markdown]
# ## Data Normalization
#
# *Data normalization* means to scale the input features of a neural
# network, so that all features are scaled similarly (similar means
# and standard deviations). Although data normalization does not directly
# prevent overfitting, normalizing your data makes the training
# problem easier.
#
# Data normalization is less of an issues for input data -- like images --
# where all input features have similar interpretations.
# All features of an image are pixel intensities, all of which are scaled
# the same way. However, if we were performing prediction of, say,
# housing prices based on a house's number of bedrooms, square footage, etc.,
# we would want each of the features to be scaled similarly. A scale
# of mean 0 and standard deviation 1 is one approach. Another approach
# is to scale each feature so that they are in the range `[0, 1]`.
#
# The PyTorch transform `transforms.ToTensor()` automatically scales
# each pixel intensity to the range `[0, 1]`.
# In your lab 2 code, we used the following transform:

# %%
transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# Out:
# Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))

# %% [markdown]
# This transform subtracts 0.5 from each pixel, and divides the
# result by 0.5. So, each pixel intensity will be in the range `[-1, 1]`.
# In general, having both positive and negative input values helps
# the network trains quickly (because of the way weights are initialized).
# Sticking with each pixel being in the range `[0, 1]` is usually fine.
#
# ## Data Augmentation
#
# While it is often expensive to gather more data, we can often
# programmatically *generate* more data points from our existing
# data set. We can make small alterations to our training set to obtain
# slightly different input data, but that is still valid.
# Common ways of obtaining new (image) data include:
#
# - Flipping each image horizontally or vertically (won't work for digit recognition, but might for other tasks)
# - Shifting each pixel a little to the left or right
# - Rotating the images a little
# - Adding noise to the image
#
# ... or even a combination of the above. For demonstration purposes, let's randomly
# rotate our digits a little to get new training samples.
#
# Here are the 20 images in our training set:

# %%
def show20(data):
    plt.figure(figsize=(10,2))
    for n, (img, label) in enumerate(data):
        if n >= 20:
            break
        plt.subplot(2, 10, n+1)
        plt.imshow(img)

mnist_imgs = datasets.MNIST('data', train=True, download=True)
show20(mnist_imgs)

# %% [markdown]
# Here are the 20 images in our training set, each rotated randomly, by up to 25 degrees.

# %%
mnist_new = datasets.MNIST('data', train=True, download=True,
                           transform=transforms.RandomRotation(25))
show20(mnist_new)

# %% [markdown]
# If we apply the transformation again, we can get images with different rotations:

# %%
mnist_new = datasets.MNIST('data', train=True, download=True, transform=transforms.RandomRotation(25))
show20(mnist_new)

# %% [markdown]
# We can augment our data set by, say, randomly rotating each training data point 100 times:

# %%
augmented_train_data = []

my_transform = transforms.Compose([
    transforms.RandomRotation(25),
    transforms.ToTensor(),
])

for i in range(100):
    mnist_new = datasets.MNIST('data', train=True, download=True, transform=my_transform)
    for j, item in enumerate(mnist_new):
        if j >= 20:
            break
        augmented_train_data.append(item)

len(augmented_train_data)
# Out:
# 2000

# %% [markdown]
# We obtain a better validation accuracy after training on our expanded dataset.

# %%
model = MNISTClassifier()
train(model, augmented_train_data, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.572

# %% [markdown]
# ## Weight Decay
#
# A more interesting technique that prevents overfitting is the idea of weight decay.
# The idea is to **penalize large weights**. We avoid large weights, because large weights
# mean that the prediction relies a lot on the content of one pixel, or on one unit. Intuitively,
# it does not make sense that the classification of an image should depend heavily on the
# content of one pixel, or even a few pixels.
#
# Mathematically, we penalize large weights by adding an extra term to the loss function,
# the term can look like the following:
#
# - $L^1$ regularization: $\sum_k |w_k|$
#     - Mathematically, this term encourages weights to be exactly 0
# - $L^2$ regularization: $\sum_k w_k^2$
#     - Mathematically, in each iteration the weight is pushed towards 0
# - Combination of $L^1$ and $L^2$ regularization: add a term $\sum_k |w_k| + w_k^2$  to the loss function.
#
# In PyTorch, weight decay can also be done automatically inside an optimizer. The parameter `weight_decay`
# of `optim.SGD` and most other optimizers uses $L^2$ regularization for weight decay. The value of the
# `weight_decay` parameter is another tunable hyperparameter.

# %%
model = MNISTClassifier()
train(model, mnist_train, mnist_val, num_iters=500, weight_decay=0.001)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.7285

# %% [markdown]
# ## Dropout
#
# Yet another way to prevent overfitting is to build **many** models, then average
# their predictions at test time. Each model might have a different set of
# initial weights.
#
# We won't show an example of model averaging here. Instead, we will show another
# idea that sounds drastically different on the surface.
#
# This idea is called **dropout**: we will randomly "drop out", "zero out", or "remove" a portion
# of neurons from each training iteration.
#
# ![](https://github.com/WilliamJWen/APS360/blob/main/tutorial/imgs/dropout.png?raw=1)
#
# In different iterations of training, we will drop out a different set of neurons.
#
# The technique has an effect of preventing weights from being overly dependent on
# each other: for example for one weight to be unnecessarily large to compensate for
# another unnecessarily large weight with the opposite sign. Weights are encouraged
# to be "more independent" of one another.
#
# During test time though, we will not drop out any neurons; instead we will use
# the entire set of weights. This means that our training time and test time behaviour
# of dropout layers are *different*. In the code for the function `train` and `get_accuracy`,
# we use `model.train()` and `model.eval()` to flag whether we want the model's training behaviour,
# or test time behaviour.
#
# While unintuitive, using all connections is a form
# of model averaging! We are effectively averaging over many different networks
# of various connectivity structures.

# %%
class MNISTClassifierWithDropout(nn.Module):
    def __init__(self):
        super(MNISTClassifierWithDropout, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 50)
        self.layer2 = nn.Linear(50, 20)
        self.layer3 = nn.Linear(20, 10)
        self.dropout1 = nn.Dropout(0.4) # drop out layer with 20% dropped out neuron
        self.dropout2 = nn.Dropout(0.4)
        self.dropout3 = nn.Dropout(0.4)
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = F.relu(self.layer1(self.dropout1(flattened)))
        activation2 = F.relu(self.layer2(self.dropout2(activation1)))
        output = self.layer3(self.dropout3(activation2))
        return output

model = MNISTClassifierWithDropout()
train(model, mnist_train, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 0.985
# Final Validation Accuracy: 0.728
